# %%
from skimage import io

# %%
img1 =io.imread('/Users/awesome_wood/Downloads/21371864_1960696994204078_1860749956281794560_n.jpg',as_grey=True)

# %%
io.imshow(img1)

# %%
print(type(img1))
# Out:
# <class 'numpy.ndarray'>

# %%
print(img1.shape)
# Out:
# (640, 640)

# %%
io.show()
